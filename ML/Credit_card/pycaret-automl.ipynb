# %%
from pycaret.classification import *
import pandas as pd
import numpy as np

from catboost import CatBoostClassifier
from sklearn.model_selection import StratifiedKFold

from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.metrics import log_loss
from tensorflow.keras.utils import to_categorical

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26457 entries, 0 to 26456
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          26457 non-null  int64
#  1   gender         26457 non-null  object
#  2   car            26457 non-null  object
#  3   reality        26457 non-null  object
#  4   child_num      26457 non-null  int64
#  5   income_total   26457 non-null  float64
#  6   income_type    26457 non-null  object
#  7   edu_type       26457 non-null  object
#  8   family_type    26457 non-null  object
#  9   house_type     26457 non-null  object
#  10  DAYS_BIRTH     26457 non-null  int64
#  11  DAYS_EMPLOYED  26457 non-null  int64
#  12  FLAG_MOBIL     26457 non-null  int64
#  13  work_phone     26457 non-null  int64
#  14  phone          26457 non-null  int64
#  15  email          26457 non-null  int64
#  16  occyp_type     18286 non-null  object
#  17  family_size    26457 non-null  float64
#  18  begin_month    26457 non-null  float64
#  19  credit         26457 non-null  float64
# dtypes: float64(4), int64(8), object(8)
# memory usage: 4.0+ MB

# %% [markdown]
# # 실험 환경 구축 (Setup the enviornment)
# PyCaret에서는 모델 학습 전 실험 환경을 구축 해주어야 합니다. setup 함수를 통해 환경을 구축할 수 있습니다.
# setup 단계에서는 PyCaret이 자동으로 컬럼 형태를 인식합니다. 그 후 사용자에게 제대로 인식되었는지 확인을 받게 됩니다.   그 때 enter를 눌러주시면 됩니다.
# 또한 주어진 데이터의 얼마를 사용하여 train / validation을 구축할지 묻게 되는데, 전체 데이터를 사용하고 싶다면 enter 눌러주시면 됩니다.
# In PyCaret you have to setup the environment before experimenting with the models. It can be done by using 'setup' method.
# In setup stage, PyCaret automatically interprets column types of the given data and asks the user if it has intepreted it correctly. You can customize whether you want each columns to be interpreted differently by using the parameters in setup method. In this tutorial we will just go with the automatic interpretation by pressing 'enter'.
# Also, it asks the ratio of dataset used to contruct train/validation sets. We will use 100% of the dataset so just press 'enter' again.

# %%
clf = setup(data = train, target = 'credit')
# Out:
# <style  type="text/css" >
# </style><table id="T_4e300_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4e300_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_4e300_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_4e300_row0_col1" class="data row0 col1" >1713</td>
#             </tr>
#             <tr>
#                         <th id="T_4e300_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_4e300_row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_4e300_row1_col1" class="data row1 col1" >credit</td>
#             </tr>
#             <tr>
#                         <th id="T_4e300_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_4e300_row2_col0" class="data row2 col0" >Target Type</td>
#                         <td id="T_4e300_row2_col1" class="data row2 col1" >Multiclass</td>
#             </tr>
#             <tr>
#                         <th id="T_4e300_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_4e300_row3_col0" class="data row3 col0" >Label Encoded</td>
#                         <td id="T_4e300_row3_col1" class="data row3 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_4e300_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_4e300_row4_col0" class="data row4 col0" >Original Data</td>
#                         <td id="T_4e300_row4_col1" class="data row4 col1" >(26457, 20)</td>
#             </tr>
#             <tr>
#                         <th id="T_4e300_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_4e300_row5_col0" class="data row5 col0" >Missing Values</td>
#                         <td id="T_4e300_row5_col1" class="data row5 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_4e300_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_4e300_row6_col0" class="data row6 col0" >Numeric Features</td>
#                         <td id="T_4e300_row6_col1" class="data row6 col1" >6</td>
#             </tr>
#             <tr>
#                         <th id="T_4e300_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_4e300_row7_col0" class="data row7 col0" >Categorical Features</td>
#                         <td id="T_4e300_row7_col1" class="data row7 col1" >13</td>
#             </tr>
#             <tr>
#                         <th id="T_4e300_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_4e300_row8_col0" class="data row8 col0" >Ordinal Features</td>
#                         <td id="T_4e300_row8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_4e300_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_4e300_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#                         <td id="T_4e300_row9_col1" class="data row9 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_4e300_level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_4e300_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#                         <td id="T_4e300_row10_col1" class="data row10 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_4e300_level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_4e300_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_4e300_row11_col1" class="data row11 col1" >(18519, 60)</td>
#             </tr>
#             <tr>
#                         <th id="T_4e300_level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_4e300_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_4e300_row12_col1" class="data row12 col1" >(7938, 60)</td>
#             </tr>
#             <tr>
#                         <th id="T_4e300_level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_4e300_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#                         <td id="T_4e300_row13_col1" class="data row13 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_4e300_level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_4e300_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#                         <td id="T_4e300_row14_col1" class="data row14 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_4e300_level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_4e300_row15_col0" class="data row15 col0" >Fold Generator</td>
#                         <td id="T_4e300_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#             </tr>
#             <tr>
#                         <th id="T_4e300_level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_4e300_row16_col0" class="data row16 col0" >Fold Number</td>
#                         <td id="T_4e300_row16_col1" class="data row16 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_4e300_level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_4e300_row17_col0" class="data row17 col0" >CPU Jobs</td>
#                         <td id="T_4e300_row17_col1" class="data row17 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_4e300_level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_4e300_row18_col0" class="data row18 col0" >Use GPU</td>
#                         <td id="T_4e300_row18_col1" class="data row18 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_4e300_level0_row19" class="row_heading level0 row19" >19</th>
#                         <td id="T_4e300_row19_col0" class="data row19 col0" >Log Experiment</td>
#                         <td id="T_4e300_row19_col1" class="data row19 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_4e300_level0_row20" class="row_heading level0 row20" >20</th>
#                         <td id="T_4e300_row20_col0" class="data row20 col0" >Experiment Name</td>
#                         <td id="T_4e300_row20_col1" class="data row20 col1" >clf-default-name</td>
#             </tr>
#             <tr>
#                         <th id="T_4e300_level0_row21" class="row_heading level0 row21" >21</th>
#                         <td id="T_4e300_row21_col0" class="data row21 col0" >USI</td>
#                         <td id="T_4e300_row21_col1" class="data row21 col1" >05d8</td>
#             </tr>
#             <tr>
#                         <th id="T_4e300_level0_row22" class="row_heading level0 row22" >22</th>
#                         <td id="T_4e300_row22_col0" class="data row22 col0" >Imputation Type</td>
#                         <td id="T_4e300_row22_col1" class="data row22 col1" >simple</td>
#             </tr>
#             <tr>
#                         <th id="T_4e300_level0_row23" class="row_heading level0 row23" >23</th>
#                         <td id="T_4e300_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#                         <td id="T_4e300_row23_col1" class="data row23 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_4e300_level0_row24" class="row_heading level0 row24" >24</th>
#                         <td id="T_4e300_row24_col0" class="data ro

# %%
#NA 처리 해주자
train.fillna('NaN',inplace = True)
test.fillna('NaN',inplace = True)

# %%
#logloss 적용 및 predict_proba로 제출하기 위해 metric 추가
add_metric('logloss', 'LogLoss', log_loss, greater_is_better=False, target="pred_proba")
# Out:
# Name                                                           LogLoss
# Display Name                                                   LogLoss
# Score Function                   <function log_loss at 0x7fe066778ca0>
# Scorer               make_scorer(log_loss, greater_is_better=False,...
# Target                                                      pred_proba
# Args                                                                {}
# Greater is Better                                                False
# Multiclass                                                        True
# Custom                                                            True
# Name: logloss, dtype: object

# %% [markdown]
# # 모델 학습 및 비교
# 환경 구축을 했으니 PyCaret에서 제공하는 기본 모델에 대해 학습하고 비교해보겠습니다.
# compared_models 함수를 통해 15개의 기본 모델을 학습하고 성능을 비교할 수 있습니다.
# log_loss 기준
# Now we have constructed the environment, we will now train and compare the default models provided in PyCaret
# By using 'compare_models' method we can easily train and compare 15 default models provided in the package

# %%
#svm, ridge는 predict_proba 미지원
best_3 = compare_models(fold = 5, sort = "logloss",n_select = 4,exclude=['svm','ridge'])
# Out:
# <style  type="text/css" >
#     #T_c5ba9_ th {
#           text-align: left;
#     }#T_c5ba9_row0_col0,#T_c5ba9_row0_col2,#T_c5ba9_row0_col3,#T_c5ba9_row0_col4,#T_c5ba9_row0_col5,#T_c5ba9_row0_col6,#T_c5ba9_row0_col7,#T_c5ba9_row1_col0,#T_c5ba9_row1_col1,#T_c5ba9_row1_col2,#T_c5ba9_row1_col3,#T_c5ba9_row1_col4,#T_c5ba9_row1_col5,#T_c5ba9_row1_col6,#T_c5ba9_row1_col7,#T_c5ba9_row1_col8,#T_c5ba9_row2_col0,#T_c5ba9_row2_col1,#T_c5ba9_row2_col2,#T_c5ba9_row2_col3,#T_c5ba9_row2_col5,#T_c5ba9_row2_col6,#T_c5ba9_row2_col7,#T_c5ba9_row2_col8,#T_c5ba9_row3_col0,#T_c5ba9_row3_col1,#T_c5ba9_row3_col2,#T_c5ba9_row3_col3,#T_c5ba9_row3_col4,#T_c5ba9_row3_col5,#T_c5ba9_row3_col6,#T_c5ba9_row3_col7,#T_c5ba9_row3_col8,#T_c5ba9_row4_col0,#T_c5ba9_row4_col1,#T_c5ba9_row4_col2,#T_c5ba9_row4_col3,#T_c5ba9_row4_col4,#T_c5ba9_row4_col5,#T_c5ba9_row4_col6,#T_c5ba9_row4_col7,#T_c5ba9_row4_col8,#T_c5ba9_row5_col0,#T_c5ba9_row5_col1,#T_c5ba9_row5_col2,#T_c5ba9_row5_col3,#T_c5ba9_row5_col4,#T_c5ba9_row5_col5,#T_c5ba9_row5_col6,#T_c5ba9_row5_col7,#T_c5ba9_row5_col8,#T_c5ba9_row6_col0,#T_c5ba9_row6_col1,#T_c5ba9_row6_col2,#T_c5ba9_row6_col3,#T_c5ba9_row6_col4,#T_c5ba9_row6_col5,#T_c5ba9_row6_col6,#T_c5ba9_row6_col7,#T_c5ba9_row6_col8,#T_c5ba9_row7_col0,#T_c5ba9_row7_col1,#T_c5ba9_row7_col4,#T_c5ba9_row7_col8,#T_c5ba9_row8_col0,#T_c5ba9_row8_col1,#T_c5ba9_row8_col2,#T_c5ba9_row8_col3,#T_c5ba9_row8_col4,#T_c5ba9_row8_col5,#T_c5ba9_row8_col6,#T_c5ba9_row8_col7,#T_c5ba9_row8_col8,#T_c5ba9_row9_col0,#T_c5ba9_row9_col1,#T_c5ba9_row9_col2,#T_c5ba9_row9_col3,#T_c5ba9_row9_col4,#T_c5ba9_row9_col5,#T_c5ba9_row9_col6,#T_c5ba9_row9_col7,#T_c5ba9_row9_col8,#T_c5ba9_row10_col0,#T_c5ba9_row10_col1,#T_c5ba9_row10_col2,#T_c5ba9_row10_col3,#T_c5ba9_row10_col4,#T_c5ba9_row10_col5,#T_c5ba9_row10_col6,#T_c5ba9_row10_col7,#T_c5ba9_row10_col8,#T_c5ba9_row11_col0,#T_c5ba9_row11_col1,#T_c5ba9_row11_col2,#T_c5ba9_row11_col3,#T_c5ba9_row11_col4,#T_c5ba9_row11_col5,#T_c5ba9_row11_col6,#T_c5ba9_row11_col7,#T_c5ba9_row11_col8,#T_c5ba9_row12_col0,#T_c5ba9_row12_col1,#T_c5ba9_row12_col2,#T_c5ba9_row12_col3,#T_c5ba9_row12_col4,#T_c5ba9_row12_col5,#T_c5ba9_row12_col6,#T_c5ba9_row12_col7,#T_c5ba9_row12_col8{
#             text-align:  left;
#             text-align:  left;
#         }#T_c5ba9_row0_col1,#T_c5ba9_row0_col8,#T_c5ba9_row2_col4,#T_c5ba9_row7_col2,#T_c5ba9_row7_col3,#T_c5ba9_row7_col5,#T_c5ba9_row7_col6,#T_c5ba9_row7_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_c5ba9_row0_col9,#T_c5ba9_row1_col9,#T_c5ba9_row2_col9,#T_c5ba9_row3_col9,#T_c5ba9_row5_col9,#T_c5ba9_row6_col9,#T_c5ba9_row7_col9,#T_c5ba9_row8_col9,#T_c5ba9_row9_col9,#T_c5ba9_row10_col9,#T_c5ba9_row11_col9,#T_c5ba9_row12_col9{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_c5ba9_row4_col9{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }</style><table id="T_c5ba9_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>        <th class="col_heading level0 col8" >LogLoss</th>        <th class="col_heading level0 col9" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c5ba9_level0_row0" class="row_heading level0 row0" >catboost</th>
#                         <td id="T_c5ba9_row0_col0" class="data row0 col0" >CatBoost Classifier</td>
#                         <td id="T_c5ba9_row0_col1" class="data row0 col1" >0.7015</td>
#                         <td id="T_c5ba9_row0_col2" class="data row0 col2" >0.6985</td>
#                         <td id="T_c5ba9_row0_col3" class="data row0 col3" >0.4420</td>
#                         <td id="T_c5ba9_row0_col4" class="data row0 col4" >0.6864</td>
#                         <td id="T_c5ba9_row0_col5" class="data row0 col5" >0.6358</td>
#                         <td id="T_c5ba9_row0_col6" class="data row0 col6" >0.2599</td>
#                         <td id="T_c5ba9_row0_col7" class="data row0 col7" >0.3255</td>
#                         <td id="T_c5ba9_row0_col8" class="data row0 col8" >0.7721</td>
#                         <td id="T_c5ba9_row0_col9" class="data row0 col9" >4.9960</td>
#             </tr>
#             <tr>
#                         <th id="T_c5ba9_level0_row1" class="row_heading level0 row1" >xgboost</th>
#                         <td id="T_c5ba9_row1_col0" class="data row1 col0" >Extreme Gradient Boosting</td>
#                         <td id="T_c5ba9_row1_col1" class="data row1 col1" >0.6991</td>
#                         <td id="T_c5ba9_row1_col2" class="data row1 col2" >0.7017</td>
#                         <td id="T_c5ba9_row1_col3" class="data row1 col3" >0.4428</td>
#                         <td id="T_c5ba9_row1_col4" class="data row1 col4" >0.6770</td>
#                         <td id="T_c5ba9_row1_col5" class="data row1 col5" >0.6354</td>
#                         <td id="T_c5ba9_row1_col6" class="data row1 col6" >0.2580</td>
#                         <td id="T_c5ba9_row1_col7" class="data row1 col7" >0.3191</td>
#                         <td id="T_c5ba9_row1_col8" class="data row1 col8" >0.7733</td>
#                         <td id="T_c5ba9_row1_col9" class="data row1 col9" >7.2400</td>
#             </tr>
#             <tr>
#                         <th id="T_c5ba9_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#                         <td id="T_c5ba9_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#                         <td id="T_c5ba9_row2_col1" class="data row2 col1" >0.6977</td>
#                         <td id="T_c5ba9_row2_col2" class="data row2 col2" >0.6918</td>
#                         <td id="T_c5ba9_row2_col3" class="data row2 col3" >0.4243</td>
#                         <td id="T_c5ba9_row2_col4" class="data row2 col4" >0.6889</td>
#                         <td id="T_c5ba9_row2_col5" class="data row2 col5" >0.6212</td>
#                         <td id="T_c5ba9_row2_col6" class="data row2 col6" >0.2321</td>
#                         <td id="T_c5ba9_row2_col7" class="data row2 col7" >0.3132</td>
#                         <td id="T_c5ba9_row2_col8" class="data row2 col8" >0.7741</td>
#                         <td id="T_c5ba9_row2_col9" class="data row2 col9" >0.9660</td>
#             </tr>
#             <tr>
#                         <th id="T_c5ba9_level0_row3" class="row_heading level0 row3" >gbc</th>
#                         <td id="T_c5ba9_row3_col0" class="data row3 col0" >Gradient Boosting Classifier</td>
#                         <td id="T_c5ba9_row3_col1" class="data row3 col1" >0.6942</td>
#                         <td id="T_c5ba9_row3_col2" class="data row3 col2" >0.6464</td>
#                         <td id="T_c5ba9_row3_col3" class="data row3 col3" >0.4102</td>
#                         <td id="T_c5ba9_row3_col4" class="data row3 col4" >0.6662</td>
#                         <td id="T_c5ba9_row3_col5" class="data row3 col5" >0.6089</td>
#                         <td id="T_c5ba9_row3_col6" class="data row3 col6" >0.2103</td>
#                         <td id="T_c5ba9_row3_col7" class="data row3 col7" >0.3029</td>
#                         <td id="T_c5ba9_row3_col8" class="data row3 col8" >0.7973</td>
#                         <td id="T_c5ba9_row3_col9" class="data row3 col9" >3.1340</td>
#             </tr>
#             <tr>
#                         <th id="T_c5ba9_level0_row4" class="row_heading level0 row4" >nb</th>
#                         <td id="T_c5ba9_row4_col0" class="data row4 col0" >Naive Bayes</td>

# %% [markdown]
# # 모델 앙상블

# %%
blended = blend_models(estimator_list = best_3, fold = 5, optimize = 'logloss', method = 'soft')
# Out:
# <style  type="text/css" >
# #T_a97ef_row5_col0,#T_a97ef_row5_col1,#T_a97ef_row5_col2,#T_a97ef_row5_col3,#T_a97ef_row5_col4,#T_a97ef_row5_col5,#T_a97ef_row5_col6,#T_a97ef_row5_col7{
#             background:  yellow;
#         }</style><table id="T_a97ef_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>        <th class="col_heading level0 col7" >LogLoss</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a97ef_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_a97ef_row0_col0" class="data row0 col0" >0.7006</td>
#                         <td id="T_a97ef_row0_col1" class="data row0 col1" >0.7040</td>
#                         <td id="T_a97ef_row0_col2" class="data row0 col2" >0.4258</td>
#                         <td id="T_a97ef_row0_col3" class="data row0 col3" >0.6929</td>
#                         <td id="T_a97ef_row0_col4" class="data row0 col4" >0.6236</td>
#                         <td id="T_a97ef_row0_col5" class="data row0 col5" >0.2362</td>
#                         <td id="T_a97ef_row0_col6" class="data row0 col6" >0.3241</td>
#                         <td id="T_a97ef_row0_col7" class="data row0 col7" >0.7610</td>
#             </tr>
#             <tr>
#                         <th id="T_a97ef_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_a97ef_row1_col0" class="data row1 col0" >0.6947</td>
#                         <td id="T_a97ef_row1_col1" class="data row1 col1" >0.6998</td>
#                         <td id="T_a97ef_row1_col2" class="data row1 col2" >0.4153</td>
#                         <td id="T_a97ef_row1_col3" class="data row1 col3" >0.6721</td>
#                         <td id="T_a97ef_row1_col4" class="data row1 col4" >0.6134</td>
#                         <td id="T_a97ef_row1_col5" class="data row1 col5" >0.2197</td>
#                         <td id="T_a97ef_row1_col6" class="data row1 col6" >0.3033</td>
#                         <td id="T_a97ef_row1_col7" class="data row1 col7" >0.7711</td>
#             </tr>
#             <tr>
#                         <th id="T_a97ef_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_a97ef_row2_col0" class="data row2 col0" >0.7038</td>
#                         <td id="T_a97ef_row2_col1" class="data row2 col1" >0.7093</td>
#                         <td id="T_a97ef_row2_col2" class="data row2 col2" >0.4323</td>
#                         <td id="T_a97ef_row2_col3" class="data row2 col3" >0.6891</td>
#                         <td id="T_a97ef_row2_col4" class="data row2 col4" >0.6302</td>
#                         <td id="T_a97ef_row2_col5" class="data row2 col5" >0.2530</td>
#                         <td id="T_a97ef_row2_col6" class="data row2 col6" >0.3333</td>
#                         <td id="T_a97ef_row2_col7" class="data row2 col7" >0.7610</td>
#             </tr>
#             <tr>
#                         <th id="T_a97ef_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_a97ef_row3_col0" class="data row3 col0" >0.6984</td>
#                         <td id="T_a97ef_row3_col1" class="data row3 col1" >0.7042</td>
#                         <td id="T_a97ef_row3_col2" class="data row3 col2" >0.4261</td>
#                         <td id="T_a97ef_row3_col3" class="data row3 col3" >0.7180</td>
#                         <td id="T_a97ef_row3_col4" class="data row3 col4" >0.6221</td>
#                         <td id="T_a97ef_row3_col5" class="data row3 col5" >0.2316</td>
#                         <td id="T_a97ef_row3_col6" class="data row3 col6" >0.3164</td>
#                         <td id="T_a97ef_row3_col7" class="data row3 col7" >0.7660</td>
#             </tr>
#             <tr>
#                         <th id="T_a97ef_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_a97ef_row4_col0" class="data row4 col0" >0.6965</td>
#                         <td id="T_a97ef_row4_col1" class="data row4 col1" >0.7055</td>
#                         <td id="T_a97ef_row4_col2" class="data row4 col2" >0.4187</td>
#                         <td id="T_a97ef_row4_col3" class="data row4 col3" >0.6825</td>
#                         <td id="T_a97ef_row4_col4" class="data row4 col4" >0.6166</td>
#                         <td id="T_a97ef_row4_col5" class="data row4 col5" >0.2245</td>
#                         <td id="T_a97ef_row4_col6" class="data row4 col6" >0.3093</td>
#                         <td id="T_a97ef_row4_col7" class="data row4 col7" >0.7677</td>
#             </tr>
#             <tr>
#                         <th id="T_a97ef_level0_row5" class="row_heading level0 row5" >Mean</th>
#                         <td id="T_a97ef_row5_col0" class="data row5 col0" >0.6988</td>
#                         <td id="T_a97ef_row5_col1" class="data row5 col1" >0.7046</td>
#                         <td id="T_a97ef_row5_col2" class="data row5 col2" >0.4236</td>
#                         <td id="T_a97ef_row5_col3" class="data row5 col3" >0.6909</td>
#                         <td id="T_a97ef_row5_col4" class="data row5 col4" >0.6212</td>
#                         <td id="T_a97ef_row5_col5" class="data row5 col5" >0.2330</td>
#                         <td id="T_a97ef_row5_col6" class="data row5 col6" >0.3173</td>
#                         <td id="T_a97ef_row5_col7" class="data row5 col7" >0.7654</td>
#             </tr>
#             <tr>
#                         <th id="T_a97ef_level0_row6" class="row_heading level0 row6" >SD</th>
#                         <td id="T_a97ef_row6_col0" class="data row6 col0" >0.0032</td>
#                         <td id="T_a97ef_row6_col1" class="data row6 col1" >0.0030</td>
#                         <td id="T_a97ef_row6_col2" class="data row6 col2" >0.0060</td>
#                         <td id="T_a97ef_row6_col3" class="data row6 col3" >0.0153</td>
#                         <td id="T_a97ef_row6_col4" class="data row6 col4" >0.0058</td>
#                         <td id="T_a97ef_row6_col5" class="data row6 col5" >0.0115</td>
#                         <td id="T_a97ef_row6_col6" class="data row6 col6" >0.0106</td>
#                         <td id="T_a97ef_row6_col7" class="data row6 col7" >0.0039</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# # 모델 예측 (prediction)

# %%
pred_holdout = predict_model(blended)

# %%
#전체 데이터를 활용한 final 학습
final_model = finalize_model(blended)

# %%
#Accurary, AUC, Logloss 셋다 상위 4개인 모델 사용
prep_pipe = get_config("prep_pipe")
prep_pipe.steps.append(['trained_model', final_model_custom])
prections = prep_pipe.predict_proba(test)
prections

# %%
i, j, k = [], [], []
for row in prections:
  i.append(row[0])
  j.append(row[1])
  k.append(row[2])

len(i), len(j), len(k)

# %%
submit['0'] = i
submit['1'] = j
submit['2'] = k
submit.head(10)
submit.to_csv(PATH+"\submisison.csv",index=False)

# %%
#결과 제출 - predict with test set
#predictions = predict_model(final_model, data = test)
#submission['credit'] = predictions['Score']
#submission.to_csv('submission_proba.csv', index = False)
